# %% [markdown]
# # Instal

# %%
# !pip install sweetviz
# !pip install pycaret
# !pip install tpot

# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels as sm
import numpy as np

# %%
df = pd.read_csv(r'tudo.csv')
df.tail()
# Out:
#             Tempo       Estação      LAT     LONG  Movimentação  Original_473  \
# 111243  2019-6-30          Brás -23.5451 -46.6162         73888            37
# 111244   2018-7-4         Moema -23.5489 -46.6388         18709            21
# 111245  2019-7-30          Brás -23.5451 -46.6162         70818            86
# 111246  2019-12-6  Vila Mariana -23.5895 -46.6346         22373            54
# 111247   2018-8-1         Moema -23.5489 -46.6388         20281             9
#
#         Original_269  Zero  Maçã-Verde  Tangerina  Citrus  Açaí-Guaraná  \
# 111243            18    10          28          4      37            39
# 111244            23     8          37         30      35            16
# 111245            32    65          20          8      20            38
# 111246            20    19          31         43      31            39
# 111247            28    33           9         43      13            37
#
#         Pêssego       TARGET    row
# 111243       43       NORMAL   4860
# 111244       33       NORMAL  16744
# 111245       17       NORMAL   4890
# 111246       43       NORMAL  14376
# 111247       10  REABASTECER  16771

# %%
df.shape
# Out:
# (111248, 15)

# %%
df.drop_duplicates(subset=['row'], inplace=True)

# %%
df.shape
# Out:
# (17007, 15)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (17007, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17007 entries, 0 to 110766
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tempo         17007 non-null  object
#  1   Estação       17007 non-null  object
#  2   LAT           17007 non-null  float64
#  3   LONG          17007 non-null  float64
#  4   Movimentação  17007 non-null  int64
#  5   Original_473  17007 non-null  int64
#  6   Original_269  17007 non-null  int64
#  7   Zero          17007 non-null  int64
#  8   Maçã-Verde    17007 non-null  int64
#  9   Tangerina     17007 non-null  int64
#  10  Citrus        17007 non-null  int64
#  11  Açaí-Guaraná  17007 non-null  int64
#  12  Pêssego       17007 non-null  int64
#  13  TARGET        17007 non-null  object
#  14  row           17007 non-null  int64
# dtypes: float64(2), int64(10), object(3)
# memory usage: 2.1+ MB

# %% [markdown]
# # SWEETVIZ

# %%
import sweetviz

# %%
report = sweetviz.analyze(df)

# %%
report.show_html('report_tnt.html')

# %% [markdown]
# # X e Y

# %%
features = ['Original_473', 'Original_269', 'Zero', 'Maçã-Verde', 'Tangerina',
       'Citrus', 'Açaí-Guaraná', 'Pêssego']
#criando nosso X e Y
X = df[features]
Y = df.TARGET

# %%
X
# Out:
#         Original_473  Original_269  Zero  ...  Citrus  Açaí-Guaraná  Pêssego
# 0                 65            16    22  ...      39            29       31
# 1                  7            45    16  ...      20            26       38
# 2                 79            36    65  ...      16            17       31
# 3                 46            60    42  ...      32            11        9
# 4                  8            37    11  ...      32            37       43
# ...              ...           ...   ...  ...     ...           ...      ...
# 106577            56            24    54  ...      43            16        6
# 108479            15            15    34  ...      17            26       28
# 108890            64            10    44  ...      43            12       21
# 109522            50             4    36  ...      30            38       26
# 110766            30            47    56  ...       7            39       13
#
# [17007 rows x 8 columns]

# %%
Y
# Out:
# 0              NORMAL
# 1              NORMAL
# 2              NORMAL
# 3              NORMAL
# 4         REABASTECER
#              ...
# 106577         NORMAL
# 108479         NORMAL
# 108890         NORMAL
# 109522         NORMAL
# 110766         NORMAL
# Name: TARGET, Length: 17007, dtype: object

# %% [markdown]
# # pycaret

# %%
from pycaret.classification import *

# %%
ml_setup = setup(data = df, target='TARGET', train_size=0.8, session_id=1234,numeric_features=features)
# Out:
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row0_col1" class="data row0 col1" >1234</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row1_col0" class="data row1 col0" >Target Type</td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row1_col1" class="data row1 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row2_col0" class="data row2 col0" >Label Encoded</td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row2_col1" class="data row2 col1" >NORMAL: 0, REABASTECER: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row3_col1" class="data row3 col1" >(17007, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row5_col1" class="data row5 col1" >12</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row6_col1" class="data row6 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row10_col1" class="data row10 col1" >(17007, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row11_col1" class="data row11 col1" >(13605, 757)</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row12_col1" class="data row12 col1" >(3402, 757)</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row16_col1" class="data row16 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id="T_22f0f2c4_f48b_11ea_9f52_0242ac1c0002row18_col1" class="data row18 col1" >None</td

# %%
compare_models(fold=10,exclude=['svm','qda','lda'])
# Out:
# <style  type="text/css" >
#     #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002 th {
#           text-align: left;
#     }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row0_col0 {
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row0_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row0_col7 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row0_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row1_col0 {
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row1_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row1_col4 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row1_col7 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row1_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row2_col0 {
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row2_col1 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row2_col6 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row2_col7 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row2_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row3_col0 {
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row3_col7 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row3_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row4_col0 {
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row4_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row4_col7 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row4_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row5_col0 {
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row5_col7 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row5_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row6_col0 {
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row6_col7 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row6_col8 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row7_col0 {
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f48c_11ea_9f52_0242ac1c0002row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_f7a72a00_f4
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=1234, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# # TPOT

# %%
from tpot import TPOTClassifier
tpot = TPOTClassifier(generations=5, verbosity=2)

# %%
tpot.export('tpot2.py')

# %% [markdown]
# # Metricas

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score

import matplotlib.pyplot as plt
import numpy as np
import itertools


def plot_confusion_matrix(cm, target_names, title='Confusion matrix', cmap=None, normalize=True):
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy
    if cmap is None:
        cmap = plt.get_cmap('Blues')
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
def avalia(y_test, y_pred): 
  print(accuracy_score(y_test, y_pred))
  print(classification_report(y_test, y_pred))
  print(confusion_matrix(y_test, y_pred))

# %% [markdown]
# # Pre-Processamento

# %%
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, random_state=687, test_size=0.2, stratify=Y)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (13605, 8)
# (3402, 8)
# (13605,)
# (3402,)

# %% [markdown]
# # Modelos

# %% [markdown]
# # XGBClassifier

# %%
from xgboost import XGBClassifier

X_train, X_test, y_train, y_test = train_test_split(X,Y, random_state=1448, test_size=0.2, stratify=Y)

XGB = XGBClassifier(learning_rate=0.001, max_depth=10, min_child_weight=8, n_estimators=100, nthread=1, subsample=0.3)

# %%
XGB.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.001, max_delta_step=0, max_depth=10,
#               min_child_weight=8, missing=None, n_estimators=100, n_jobs=1,
#               nthread=1, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=0.3, verbosity=1)

# %%
y_XGB = XGB.predict(X_test)

# %%
avalia(y_test,y_XGB)
# Out:
# 0.8004115226337448
#               precision    recall  f1-score   support
#
#       NORMAL       0.99      0.71      0.83      2303
#  REABASTECER       0.62      0.98      0.76      1099
#
#     accuracy                           0.80      3402
#    macro avg       0.80      0.85      0.79      3402
# weighted avg       0.87      0.80      0.81      3402
#
# [[1643  660]
#  [  19 1080]]

# %%
plot_confusion_matrix(confusion_matrix(y_test, y_XGB), ['NORMAL', 'REABASTECER'])

# %% [markdown]
# # LGBMClassifier

# %%
from lightgbm import LGBMClassifier 

X_train, X_test, y_train, y_test = train_test_split(X,Y, random_state=717, test_size=0.2, stratify=Y)

LGBM = LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
               importance_type='split', learning_rate=0.1, max_depth=-1,
               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
               random_state=1234, reg_alpha=0.0, reg_lambda=0.0, silent=True,
               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
LGBM.fit(X_train, y_train)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=1234, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
y_LGBM = LGBM.predict(X_test)

# %%
avalia(y_test,y_LGBM)
# Out:
# 0.7739564961787184
#               precision    recall  f1-score   support
#
#       NORMAL       0.90      0.75      0.82      2303
#  REABASTECER       0.61      0.83      0.70      1099
#
#     accuracy                           0.77      3402
#    macro avg       0.76      0.79      0.76      3402
# weighted avg       0.81      0.77      0.78      3402
#
# [[1722  581]
#  [ 188  911]]

# %%
plot_confusion_matrix(confusion_matrix(y_test, y_LGBM), ['NORMAL', 'REABASTECER'])

# %% [markdown]
#  # pegando o melhor

# %%
for x in range(1000,2000): 
  print(x)  
  X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state=x)
  
  y_XGB = XGB.fit(X_train, y_train).predict(X_test)

  y_LGBM = LGBM.fit(X_train, y_train).predict(X_test)  

  if (accuracy_score(y_test, y_XGB)*100) > 79.5:
    
    print("XGB:",accuracy_score(y_test, y_XGB)*100)

  if (accuracy_score(y_test, y_LGBM)*100) > 78.5:
  
    print("LGBM:",accuracy_score(y_test, y_LGBM)*100)
    

  print('\n')
# Out:
# 1000
#
#
# 1001
#
#
# 1002
#
#
# 1003
#
#
# 1004
#
#
# 1005
#
#
# 1006
#
#
# 1007
# XGB: 79.8447789275635
#
#
# 1008
#
#
# 1009
#
#
# 1010
#
#
# 1011
#
#
# 1012
#
#
# 1013
#
#
# 1014
#
#
# 1015
#
#
# 1016
#
#
# 1017
#
#
# 1018
#
#
# 1019
#
#
# 1020
#
#
# 1021
#
#
# 1022
#
#
# 1023
#
#
# 1024
#
#
# 1025
#
#
# 1026
#
#
# 1027
#
#
# 1028
#
#
# 1029
#
#
# 1030
#
#
# 1031
#
#
# 1032
#
#
# 1033
#
#
# 1034
#
#
# 1035
#
#
# 1036
#
#
# 1037
#
#
# 1038
#
#
# 1039
#
#
# 1040
#
#
# 1041
#
#
# 1042
#
#
# 1043
#
#
# 1044
#
#
# 1045
#
#
# 1046
#
#
# 1047
#
#
# 1048
#
#
# 1049
#
#
# 1050
#
#
# 1051
#
#
# 1052
#
#
# 1053
#
#
# 1054
# XGB: 79.70366886171215
#
#
# 1055
#
#
# 1056
#
#
# 1057
#
#
# 1058
#
#
# 1059
#
#
# 1060
#
#
# 1061
#
#
# 1062
#
#
# 1063
#
#
# 1064
#
#
# 1065
#
#
# 1066
#
#
# 1067
#
#
# 1068
#
#
# 1069
# XGB: 79.56255879586077
#
#
# 1070
#
#
# 1071
#
#
# 1072
#
#
# 1073
#
#
# 1074
#
#
# 1075
#
#
# 1076
#
#
# 1077
#
#
# 1078
#
#
# 1079
#
#
# 1080
#
#
# 1081
#
#
# 1082
#
#
# 1083
#
#
# 1084
#
#
# 1085
#
#
# 1086
#
#
# 1087
#
#
# 1088
#
#
# 1089
#
#
# 1090
#
#
# 1091
# XGB: 79.68015051740358
#
#
# 1092
#
#
# 1093
#
#
# 1094
#
#
# 1095
#
#
# 1096
#
#
# 1097
#
#
# 1098
#
#
# 1099
#
#
# 1100
#
#
# 1101
#
#
# 1102
#
#
# 1103
#
#
# 1104
#
#
# 1105
#
#
# 1106
#
#
# 1107
#
#
# 1108
#
#
# 1109
#
#
# 1110
#
#
# 1111
#
#
# 1112
# XGB: 79.82126058325494
#
#
# 1113
#
#
# 1114
#
#
# 1115
#
#
# 1116
# XGB: 79.93885230479775
#
#
# 1117
#
#
# 1118
#
#
# 1119
#
#
# 1120
#
#
# 1121
#
#
# 1122
#
#
# 1123
#
#
# 1124
#
#
# 1125
#
#
# 1126
# XGB: 79.53904045155221
#
#
# 1127
#
#
# 1128
#
#
# 1129
#
#
# 1130
#
#
# 1131
# XGB: 79.51552210724365
#
#
# 1132
#
#
# 1133
#
#
#
#
# 1914
#
#
# 1915
# XGB: 79.77422389463781
#
#
# 1916
#
#
# 1917
#
#
# 1918
#
#
# 1919
#
#
# 1920
#
#
# 1921
#
#
# 1922
#
#
# 1923
# XGB: 80.05644402634054
#
#
# 1924
#
#
# 1925
#
#
# 1926
#
#
# 1927
#
#
# 1928
#
#
# 1929
#
#
# 1930
#
#
# 1931
#
#
# 1932
#
#
# 1933
#
#
# 1934
#
#
# 1935
#
#
# 1936
#
#
# 1937
#
#
# 1938
#
#
# 1939
#
#
# 1940
#
#
# 1941
#
#
# 1942
#
#
# 1943
# XGB: 79.56255879586077
#
#
# 1944
# XGB: 79.53904045155221
#
#
# 1945
#
#
# 1946
#
#
# 1947
#
#
# 1948
#
#
# 1949
#
#
# 1950
#
#
# 1951
#
#
# 1952
#
#
# 1953
#
#
# 1954
#
#
# 1955
#
#
# 1956
#
#
# 1957
#
#
# 1958
#
#
# 1959
#
#
# 1960
#
#
# 1961
#
#
# 1962
#
#
# 1963
#
#
# 1964
#
#
# 1965
#
#
# 1966
#
#
# 1967
#
#
# 1968
#
#
# 1969
#
#
# 1970
#
#
# 1971
#
#
# 1972
#
#
# 1973
#
#
# 1974
#
#
# 1975
#
#
# 1976
#
#
# 1977
#
#
# 1978
#
#
# 1979
#
#
# 1980
#
#
# 1981
#
#
# 1982
# XGB: 79.7271872060207
#
#
# 1983
#
#
# 1984
#
#
# 1985
#
#
# 1986
#
#
# 1987
#
#
# 1988
#
#
# 1989
#
#
# 1990
#
#
# 1991
#
#
# 1992
#
#
# 1993
#
#
# 1994
#
#
# 1995
#
#
# 1996
#
#
# 1997
#
#
# 1998
#
#
# 1999

# %% [markdown]
# # Entrega

# %%
# !wget --no-check-certificate --content-disposition https://gitlab.com/JoaoPedroPP/datasets/-/raw/master/ntn/to_be_scored.csv
df_to_be_scored = pd.read_csv(r'to_be_scored.csv')
df_to_be_scored.tail()
# Out:
# --2020-09-12 02:27:19--  https://gitlab.com/JoaoPedroPP/datasets/-/raw/master/ntn/to_be_scored.csv
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘to_be_scored.csv’
#
# to_be_scored.csv        [ <=>                ]  68.64K  --.-KB/s    in 0.01s
#
# 2020-09-12 02:27:19 (5.26 MB/s) - ‘to_be_scored.csv’ saved [70291]
#          Tempo             Estação      LAT  ...  Citrus  Açaí-Guaraná  Pêssego
# 979  2019-8-19  Hospital São Paulo -23.5984  ...      27             6        2
# 980  2019-8-20  Hospital São Paulo -23.5984  ...      22            43       43
# 981  2019-8-21  Hospital São Paulo -23.5984  ...      17            37       37
# 982  2019-8-22  Hospital São Paulo -23.5984  ...      12            33       33
# 983  2019-8-23  Hospital São Paulo -23.5984  ...       7            27       27
#
# [5 rows x 13 columns]

# %%
df_to_be_scored = pd.read_csv('to_be_scored.csv')
df_to_be_scored.tail()
# Out:
#          Tempo             Estação      LAT  ...  Citrus  Açaí-Guaraná  Pêssego
# 979  2019-8-19  Hospital São Paulo -23.5984  ...      27             6        2
# 980  2019-8-20  Hospital São Paulo -23.5984  ...      22            43       43
# 981  2019-8-21  Hospital São Paulo -23.5984  ...      17            37       37
# 982  2019-8-22  Hospital São Paulo -23.5984  ...      12            33       33
# 983  2019-8-23  Hospital São Paulo -23.5984  ...       7            27       27
#
# [5 rows x 13 columns]

# %%
df_to_be_scored.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tempo         984 non-null    object
#  1   Estação       984 non-null    object
#  2   LAT           984 non-null    float64
#  3   LONG          984 non-null    float64
#  4   Movimentação  984 non-null    int64
#  5   Original_473  984 non-null    int64
#  6   Original_269  984 non-null    int64
#  7   Zero          984 non-null    int64
#  8   Maçã-Verde    984 non-null    int64
#  9   Tangerina     984 non-null    int64
#  10  Citrus        984 non-null    int64
#  11  Açaí-Guaraná  984 non-null    int64
#  12  Pêssego       984 non-null    int64
# dtypes: float64(2), int64(9), object(2)
# memory usage: 100.1+ KB

# %% [markdown]
# # Classificar

# %%
from sklearn.impute import SimpleImputer
import numpy as np


impute_zeros = SimpleImputer(
    missing_values=np.nan,
    strategy='constant',
    fill_value=0,
    verbose=0,
    copy=True
)

# %%
# 1 - Removendo linhas com valores NaN
df_to_be_scored_1 = df_to_be_scored.dropna(axis='index', how='any', subset=['Tempo', 'Estação', 'LAT', 'LONG', 'Movimentação', 'Original_473', 'Original_269', 'Zero', 'Maçã-Verde', 'Tangerina', 'Citrus', 'Açaí-Guaraná', 'Pêssego'])

# 2 - Inputando zeros nos valores faltantes
impute_zeros.fit(X=df_to_be_scored_1)
df_to_be_scored_2 = pd.DataFrame.from_records(
    data=impute_zeros.transform(
        X=df_to_be_scored_1
    ),
    columns=df_to_be_scored_1.columns
)

# 3 - Remoção de colunas
df_to_be_scored_3 = df_to_be_scored_2.drop(columns=['Tempo', 'Estação', 'LAT', 'LONG', 'Movimentação', 'Estação'], inplace=False)

# 4 - Encoding com "dummy variables" (se necessário)
# df_to_be_scored_4 = pd.get_dummies(df_to_be_scored_3, columns=['Váriavel com dummy'])
df_to_be_scored_4 = df_to_be_scored_3

df_to_be_scored_4.tail()
# Out:
#      Original_473  Original_269  Zero  ...  Citrus  Açaí-Guaraná  Pêssego
# 979            34            65    28  ...      27             6        2
# 980            21            60    18  ...      22            43       43
# 981             9            56    13  ...      17            37       37
# 982            86            49     7  ...      12            33       33
# 983            74            41    65  ...       7            27       27
#
# [5 rows x 8 columns]

# %%
df[
    [
        'Original_473', 'Original_269', 'Zero', 'Maçã-Verde', 'Tangerina',
       'Citrus', 'Açaí-Guaraná', 'Pêssego'
    ]
].columns
# Out:
# Index(['Original_473', 'Original_269', 'Zero', 'Maçã-Verde', 'Tangerina',
#        'Citrus', 'Açaí-Guaraná', 'Pêssego'],
#       dtype='object')

# %%
df_to_be_scored_4.columns
# Out:
# Index(['Original_473', 'Original_269', 'Zero', 'Maçã-Verde', 'Tangerina',
#        'Citrus', 'Açaí-Guaraná', 'Pêssego'],
#       dtype='object')

# %%
y_pred = XGB.predict(df_to_be_scored_4)
df_to_be_scored_4['TARGET'] = y_pred
df_to_be_scored_4.tail()
# Out:
#      Original_473  Original_269  Zero  ...  Açaí-Guaraná  Pêssego       TARGET
# 979            34            65    28  ...             6        2  REABASTECER
# 980            21            60    18  ...            43       43       NORMAL
# 981             9            56    13  ...            37       37  REABASTECER
# 982            86            49     7  ...            33       33  REABASTECER
# 983            74            41    65  ...            27       27       NORMAL
#
# [5 rows x 9 columns]

# %%
#project.save_data(file_name="results.csv", data=df_to_be_scored_4.to_csv(index=False))
df_to_be_scored_4.to_csv('results2.csv',index=False)
